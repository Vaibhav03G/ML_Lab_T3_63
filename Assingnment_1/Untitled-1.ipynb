# %%
import pandas as pd
import numpy as np

# %%
#To read the csv file

df = pd.read_csv('OLX_cars_dataset00.csv')
df.head()
# Out:
#         Ad ID                               Car Name      Make  Model  Year  \
# 0  1079071571           fresh import Passo 2021model    Toyota  Passo  2021
# 1  1080125520                            Suzuki ravi    Suzuki   Ravi  2018
# 2  1080748789  Suzuki bolan 2015 contact 03112271054    Suzuki  Bolan  2015
# 3  1076081635                     Diahatsu Move 2013  Daihatsu   Move  2013
# 4  1080812928     Suzuki Swift DLX 2011 miner tuchap    Suzuki  Swift  2011
#
#    KM's driven    Price    Fuel Registration city Car documents  Assembly  \
# 0        54000  4190000  Petrol      Unregistered      Original  Imported
# 1        95000  1300000  Petrol           Karachi      Original     Local
# 2        50000   800000  Petrol           Karachi      Original     Local
# 3        94000  2155000  Petrol            Lahore      Original  Imported
# 4       126544  1440000  Petrol           Karachi      Original     Local
#
#   Transmission Condition            Seller Location  \
# ...

# %%
#to drop/remove/delete the the columns

to_drop = ["Images URL's",
            'Car Profile',
            'Seller Location',
            'Registration city',
            'Description'
            ]

df.drop(to_drop, inplace=True, axis=1)

# %%
#to see the all data 

df.head()
# Out:
#         Ad ID                               Car Name      Make  Model  Year  \
# 0  1079071571           fresh import Passo 2021model    Toyota  Passo  2021
# 1  1080125520                            Suzuki ravi    Suzuki   Ravi  2018
# 2  1080748789  Suzuki bolan 2015 contact 03112271054    Suzuki  Bolan  2015
# 3  1076081635                     Diahatsu Move 2013  Daihatsu   Move  2013
# 4  1080812928     Suzuki Swift DLX 2011 miner tuchap    Suzuki  Swift  2011
#
#    KM's driven    Price    Fuel Car documents  Assembly Transmission  \
# 0        54000  4190000  Petrol      Original  Imported    Automatic
# 1        95000  1300000  Petrol      Original     Local       Manual
# 2        50000   800000  Petrol      Original     Local       Manual
# 3        94000  2155000  Petrol      Original  Imported    Automatic
# 4       126544  1440000  Petrol      Original     Local       Manual
#
#   Condition                                       Car Features
# ...

# %%
#to make the unique data

df['Make'].is_unique
True
# Out:
# True

# %%
#changing the index of the data

df = df.set_index('Make')
df.head()
# Out:
#                Ad ID                               Car Name  Model  Year  \
# Make
# Toyota    1079071571           fresh import Passo 2021model  Passo  2021
# Suzuki    1080125520                            Suzuki ravi   Ravi  2018
# Suzuki    1080748789  Suzuki bolan 2015 contact 03112271054  Bolan  2015
# Daihatsu  1076081635                     Diahatsu Move 2013   Move  2013
# Suzuki    1080812928     Suzuki Swift DLX 2011 miner tuchap  Swift  2011
#
#           KM's driven    Price    Fuel Car documents  Assembly Transmission  \
# Make
# Toyota          54000  4190000  Petrol      Original  Imported    Automatic
# Suzuki          95000  1300000  Petrol      Original     Local       Manual
# Suzuki          50000   800000  Petrol      Original     Local       Manual
# Daihatsu        94000  2155000  Petrol      Original  Imported    Automatic
# Suzuki         126544  1440000  Petrol      Original     Local       Manual
#
# ...

# %%
#changed the name of the column

new_column_names = {
        "Make": "Company_name",
        "Ad ID": "CAr_ID",
    }
   
data = df.rename(columns=new_column_names)

# %%
#to see the data

data.columns
# Out:
# Index(['CAr_ID', 'Car Name', 'Model', 'Year', 'KM's driven', 'Price', 'Fuel',
#        'Car documents', 'Assembly', 'Transmission', 'Condition',
#        'Car Features'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9179 entries, Toyota to Daihatsu
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CAr_ID         9179 non-null   int64
#  1   Car Name       9179 non-null   object
#  2   Model          9179 non-null   object
#  3   Year           9179 non-null   int64
#  4   KM's driven    9179 non-null   int64
#  5   Price          9179 non-null   int64
#  6   Fuel           9179 non-null   object
#  7   Car documents  9179 non-null   object
#  8   Assembly       9179 non-null   object
#  9   Transmission   9179 non-null   object
#  10  Condition      9179 non-null   object
#  11  Car Features   9179 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 932.2+ KB

# %%
#duplicate data

data.loc[data.duplicated(keep=False)]
# Out:
#             CAr_ID                                     Car Name       Model  \
# Make
# Suzuki  1079496823                     WagonR AGS total genuine     Wagon R
# Suzuki  1080826824                            Wagon R  2014 VXL     Wagon R
# Suzuki  1080755995  eminent blue mehran vxr 2009 model for sale  Mehran VXR
# Suzuki  1080780702                                        swift       Swift
# Suzuki  1080786841                            foll saond sistam      Baleno
# ...            ...                                          ...         ...
# Suzuki  1080315225                       2018 in good condition  Mehran VXR
# Toyota  1080195710                             toyota Yaris Gli       Yaris
# Suzuki  1080824857                    Govt. Officer Wagon R VXL     Wagon R
# Suzuki  1080360303                     suzuki cultus Model 2010  Cultus VXR
# Suzuki  1080778272                        Suzuki Swift Dlx 2018       Swift
#
# ...

# %%
#to count the rows and columns

print(df.shape)  #result is (rows,coloums)
# Out:
# (9179, 12)

# %%
#top 5 rows

df.head(5)
# Out:
#                Ad ID                               Car Name  Model  Year  \
# Make
# Toyota    1079071571           fresh import Passo 2021model  Passo  2021
# Suzuki    1080125520                            Suzuki ravi   Ravi  2018
# Suzuki    1080748789  Suzuki bolan 2015 contact 03112271054  Bolan  2015
# Daihatsu  1076081635                     Diahatsu Move 2013   Move  2013
# Suzuki    1080812928     Suzuki Swift DLX 2011 miner tuchap  Swift  2011
#
#           KM's driven    Price    Fuel Car documents  Assembly Transmission  \
# Make
# Toyota          54000  4190000  Petrol      Original  Imported    Automatic
# Suzuki          95000  1300000  Petrol      Original     Local       Manual
# Suzuki          50000   800000  Petrol      Original     Local       Manual
# Daihatsu        94000  2155000  Petrol      Original  Imported    Automatic
# Suzuki         126544  1440000  Petrol      Original     Local       Manual
#
# ...

# %%
#for counting data from the dataset

df['Year'].value_counts()
# Out:
# Year
# 2018    601
# 2017    563
# 2007    551
# 2015    537
# 2016    535
# 2006    524
# 2021    499
# 2005    484
# 2014    466
# 2012    422
# 2013    415
# 2011    396
# 2008    385
# 2019    384
# 2004    365
# 2010    355
# 2020    338
# 2022    327
# 2009    278
# 2003    259
# 2001    166
# 2002    159
# 2000    112
# 2023     55
# 1993      1
# 1989      1
# 2024      1
# Name: count, dtype: int64

# %%
#displayinf last five rows of dataset
data.tail()
# Out:
#               CAr_ID                                     Car Name    Model  \
# Make
# Suzuki    1080606577  Suzuki Wagon R Japanese 660cc sale/exchange  Wagon R
# Suzuki    1080268395                             wegon R VXL 2017  Wagon R
# KIA       1080570925                               Good condition  Spectra
# Suzuki    1075792717                              Suzuki Alto vxr     Alto
# Daihatsu  1080569552                                  Move Custom     Move
#
#           Year  KM's driven    Price    Fuel Car documents  Assembly  \
# Make
# Suzuki    2014       115000  2725000  Petrol      Original  Imported
# Suzuki    2017       100000  1850000  Petrol      Original     Local
# KIA       2001       123456  1100000  Petrol      Original  Imported
# Suzuki    2009        89000   970000  Petrol      Original  Imported
# Daihatsu  2016        95000  2050000  Petrol      Original  Imported
#
#          Transmission Condition  \
# Make
# Suzuki      Automatic      Used
# ...

# %%
data.duplicated()
# Out:
# Make
# Toyota      False
# Suzuki      False
# Suzuki      False
# Daihatsu    False
# Suzuki      False
#             ...
# Suzuki      False
# Suzuki      False
# KIA         False
# Suzuki      False
# Daihatsu    False
# Length: 9179, dtype: bool
